# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from PIL import Image

# %%
path = os.path.join('..', 'data', 'ImageNetSubset', 'train')
print('Training path:', path, '\n')

class_names = os.listdir(path)
print('Class folder names:', class_names, '\n')

for c in class_names:
    path =  os.path.join('..', 'data', 'ImageNetSubset', 'train', c)
    images = os.listdir(path)

    for i in images[:10]: # only first 3 each
        path = os.path.join('..', 'data', 'ImageNetSubset', 'train', c, i)
        print(f'Image ({c}) path: {path}')

        with Image.open(path) as image:
            print('Resolution:', image.size, '\n')
# Out:
# Training path: ../data/ImageNetSubset/train
#
# Class folder names: ['remote_control', 'computer_keyboard', 'coffee_mug', 'wooden_spoon', 'binder', 'soup_bowl', 'mouse', 'toilet_tissue', 'notebook', 'teapot']
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_7643.JPEG
# Resolution: (500, 375)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_3600.JPEG
# Resolution: (500, 375)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_39912.JPEG
# Resolution: (404, 342)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_4080.JPEG
# Resolution: (250, 576)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_1282.JPEG
# Resolution: (500, 333)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_11582.JPEG
# Resolution: (500, 375)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_28315.JPEG
# Resolution: (500, 333)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_8109.JPEG
# Resolution: (800, 560)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_40974.JPEG
# Resolution: (700, 700)
#
# Image (remote_control) path: ../data/ImageNetSubset/train/remote_control/n04074963_14153.JPEG
# Resolution: (500, 380)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_18623.JPEG
# Resolution: (500, 375)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_22698.JPEG
# Resolution: (500, 375)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_13829.JPEG
# Resolution: (600, 400)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_15504.JPEG
# Resolution: (500, 375)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_17305.JPEG
# Resolution: (500, 375)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_19065.JPEG
# Resolution: (500, 333)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_25809.JPEG
# Resolution: (500, 375)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_18674.JPEG
# Resolution: (500, 375)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_23877.JPEG
# Resolution: (500, 400)
#
# Image (computer_keyboard) path: ../data/ImageNetSubset/train/computer_keyboard/n03085013_7573.JPEG
# Resolution: (1267, 950)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_2137.JPEG
# Resolution: (324, 500)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_4149.JPEG
# Resolution: (500, 334)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_3726.JPEG
# Resolution: (389, 500)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_2422.JPEG
# Resolution: (475, 443)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_4775.JPEG
# Resolution: (375, 500)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_5164.JPEG
# Resolution: (500, 333)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_3819.JPEG
# Resolution: (411, 500)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_5021.JPEG
# Resolution: (500, 333)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_4260.JPEG
# Resolution: (500, 333)
#
# Image (coffee_mug) path: ../data/ImageNetSubset/train/coffee_mug/n03063599_2530.JPEG
# Resolution: (462, 450)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_3582.JPEG
# Resolution: (500, 333)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_3428.JPEG
# Resolution: (500, 271)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_4302.JPEG
# Resolution: (500, 436)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_1550.JPEG
# Resolution: (333, 500)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_4752.JPEG
# Resolution: (468, 500)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_378.JPEG
# Resolution: (500, 375)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_1803.JPEG
# Resolution: (500, 335)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_10777.JPEG
# Resolution: (328, 500)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_4181.JPEG
# Resolution: (500, 360)
#
# Image (wooden_spoon) path: ../data/ImageNetSubset/train/wooden_spoon/n04597913_4928.JPEG
# Resolution: (332, 500)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_8312.JPEG
# Resolution: (250, 251)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_9850.JPEG
# Resolution: (500, 375)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_6530.JPEG
# Resolution: (500, 333)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_9295.JPEG
# Resolution: (1024, 768)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_8200.JPEG
# Resolution: (296, 311)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_1021.JPEG
# Resolution: (130, 130)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_11123.JPEG
# Resolution: (160, 121)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_9104.JPEG
# Resolution: (260, 199)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_1534.JPEG
# Resolution: (500, 500)
#
# Image (binder) path: ../data/ImageNetSubset/train/binder/n02840245_2898.JPEG
# Resolution: (500, 334)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_2011.JPEG
# Resolution: (500, 400)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_8762.JPEG
# Resolution: (500, 500)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_1810.JPEG
# Resolution: (500, 375)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_5500.JPEG
# Resolution: (500, 334)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_13832.JPEG
# Resolution: (500, 375)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_17522.JPEG
# Resolution: (500, 333)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_2416.JPEG
# Resolution: (500, 333)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_2046.JPEG
# Resolution: (500, 333)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_10434.JPEG
# Resolution: (500, 375)
#
# Image (soup_bowl) path: ../data/ImageNetSubset/train/soup_bowl/n04263257_4192.JPEG
# Resolution: (500, 375)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_8791.JPEG
# Resolution: (500, 375)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_3831.JPEG
# Resolution: (500, 333)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_6760.JPEG
# Resolution: (500, 334)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_5265.JPEG
# Resolution: (500, 375)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_15702.JPEG
# Resolution: (824, 761)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_3923.JPEG
# Resolution: (500, 333)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_7960.JPEG
# Resolution: (288, 352)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_5818.JPEG
# Resolution: (500, 323)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_10445.JPEG
# Resolution: (500, 375)
#
# Image (mouse) path: ../data/ImageNetSubset/train/mouse/n03793489_51299.JPEG
# Resolution: (550, 439)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_50233.JPEG
# Resolution: (500, 334)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_34172.JPEG
# Resolution: (500, 333)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_16003.JPEG
# Resolution: (500, 375)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_39486.JPEG
# Resolution: (500, 363)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_6413.JPEG
# Resolution: (500, 375)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_38278.JPEG
# Resolution: (333, 500)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_15855.JPEG
# Resolution: (500, 375)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_7486.JPEG
# Resolution: (1050, 750)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_8773.JPEG
# Resolution: (550, 397)
#
# Image (toilet_tissue) path: ../data/ImageNetSubset/train/toilet_tissue/n15075141_6297.JPEG
# Resolution: (500, 375)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_14590.JPEG
# Resolution: (500, 500)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_8468.JPEG
# Resolution: (450, 291)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_13890.JPEG
# Resolution: (500, 352)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_14343.JPEG
# Resolution: (500, 333)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_386.JPEG
# Resolution: (500, 446)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_14713.JPEG
# Resolution: (500, 355)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_7725.JPEG
# Resolution: (500, 375)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_2177.JPEG
# Resolution: (334, 500)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_30132.JPEG
# Resolution: (500, 333)
#
# Image (notebook) path: ../data/ImageNetSubset/train/notebook/n03832673_12413.JPEG
# Resolution: (500, 375)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_3903.JPEG
# Resolution: (500, 500)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_7413.JPEG
# Resolution: (375, 500)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_18096.JPEG
# Resolution: (500, 302)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_32187.JPEG
# Resolution: (500, 332)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_23796.JPEG
# Resolution: (500, 375)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_6652.JPEG
# Resolution: (500, 375)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_10275.JPEG
# Resolution: (500, 351)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_4815.JPEG
# Resolution: (500, 320)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_4546.JPEG
# Resolution: (375, 500)
#
# Image (teapot) path: ../data/ImageNetSubset/train/teapot/n04398044_3329.JPEG
# Resolution: (500, 375)

# %%
path = "../data/ImageNetSubset/train/soup_bowl/n04263257_5500.JPEG" # windows file path type

plt.imshow(mpimg.imread(path))
